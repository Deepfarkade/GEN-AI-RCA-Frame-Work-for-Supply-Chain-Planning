# %%
api_key = vn.get_api_key('my-email@example.com')
vn.set_api_key(api_key)

# %%
import vanna as vn
from dotenv import load_dotenv
import os

# %%
load_dotenv()
os.environ['REQUESTS_CA_BUNDLE'] = 'cert.crt'
vn.set_api_key(os.environ.get("VANNA_API_KEY"))

# %%
# Set Your Model (Choose a unique model name)
#vn.set_model('GEN-AI-model',db_)
vn.create_model(model='esp_model',db_type="SQL_SERVER")
# Out:
# False

# %%
vn.get_models()
# Out:
# ['gen-ai-model',
#  '1234',
#  'esp_model',
#  'demo-tpc-h',
#  'tpc',
#  'chinook',
#  'thelook']

# %%
from sql_execution import execute_sql_query
vn.set_model('esp_model')
vn.run_sql = execute_sql_query
vn.run_sql_is_set = True

# %%
# The information schema query may need some tweaking depending on your database. This is a good starting point.
df_information_schema = vn.run_sql("SELECT TABLE_CATALOG, TABLE_SCHEMA,TABLE_NAME, COLUMN_NAME, DATA_TYPE FROM INFORMATION_SCHEMA.COLUMNS")

# This will break up the information schema into bite-sized chunks that can be referenced by the LLM
plan = vn.get_training_plan_generic(df_information_schema)
plan

# If you like the plan, then uncomment this and run it to train
vn.train(plan=plan)

# %%
# At any time you can inspect what training data the package is able to reference
training_data = vn.get_training_data()
training_data
# Out:
#            id training_data_type  \
# 0   64160-doc      documentation
# 1   68275-sql                sql
# 2   68299-sql                sql
# 3   92452-sql                sql
# 4   68290-sql                sql
# 5   64157-doc      documentation
# 6   96360-sql                sql
# 7   68354-sql                sql
# 8   20059-ddl                ddl
# 9   68258-sql                sql
# 10  68293-sql                sql
# 11  92523-sql                sql
# 12  64170-doc      documentation
# 13  68365-sql                sql
# 14  68341-sql                sql
# 15  92321-sql                sql
# 16  68253-sql                sql
# 17  68335-sql                sql
# 18  96370-sql                sql
# 19  64156-doc      documentation
# 20  92533-sql                sql
# 21  68268-sql                sql
# 22  68262-sql                sql
# 23  68279-sql                sql
# 24  64172-doc      documentation
# 25  96343-sql                sql
# 26  96341-sql                sql
# ...

# %%
# Sometimes you may want to add documentation about your business terminology or definitions. 
vn.train(documentation="How to use my most underutilised Resource then begin with, consider the scenario of underutilized resources. The query must first identify the affected product group, such as PPGI, and then systematically trace its production path through various intermediate products, including GI, TIN, CRCA, CRFH, HR, and SLAB, until reaching the origin, HOT METAL from RESPROJSTATIC Table. For instance, for PPGI, filter UDC_PRODUCT_GROUP from RESPROJSTATIC Table and identify all the resources STARTDATE wise and its AVAILCAP multiply with Average of UDC_PRODRATE Column for each RES,STARTDATE, UDC_PRODUCT_GROUP  wise in RESPROJSTATIC Table and calculate the estimated coverage demand which is equal to AVAILCAP multiply with Average of UDC_PRODRATE Column in RESPROJSTATIC Table And it should work same for all the UDC_PRODUCT_GROUP lying in the supply sequence which is equal to GI, TIN, CRCA, CRFH, HR, and SLAB, until reaching the origin, HOT METAL .PRODUCT GROUP	SUPPLY ITEMS PPGI	PPGI>GI>CRFH>HR>SLAB>HOT_METAL,  GI	GI>CRFH>HR>SLAB>HOT_METAL ,TIN	TIN>TMBP>CRAN>CRFH>HRPO>HR>SLAB>HOT_METAL ,CRCA	CRCA>CRFH>HR>SLAB>HOT_METAL ,CRFH	CRFH>HR>SLAB>HOT_METAL ,HR	HR>SLAB>HOT_METAL, SLAB	SLAB>HOT_METAL")
# Out:
# Adding documentation....
# True

# %%
# At any time you can inspect what training data the package is able to reference
training_data = vn.get_training_data()
training_data
# Out:
#             id training_data_type  \
# 0   107901-sql                sql
# 1    64160-doc      documentation
# 2    68275-sql                sql
# 3   107890-sql                sql
# 4    68299-sql                sql
# ..         ...                ...
# 72  107931-sql                sql
# 73   68347-sql                sql
# 74   68286-sql                sql
# 75   68296-sql                sql
# 76   68350-sql                sql
#
#                                              question  \
# 0   What is the outward sales for all plants, all ...
# 1                                                None
# 2   give me the underutilised resources for decemb...
# 3   What is the inward HR cosumption for coated pl...
# 4   give me the count of items  for which the reso...
# ..                                                ...
# 72  What are the column names and data types of a ...
# 73           give me the details of my overall schema
# 74  give me the underutilised resources for decemb...
# ...

# %%
# DDL statements are powerful because they specify table names, colume names, types, and potentially relationships
vn.train(ddl="""
CREATE TABLE dbo.INDDMDLINK (
    DMDITEM VARCHAR(MAX),
    DMDLOC VARCHAR(MAX),
    RELATEDSEQNUM VARCHAR(MAX),
    ORDERID VARCHAR(MAX),
    SHIPDATE DATE,
    DMDSEQNUM VARCHAR(MAX),
    DMDTYPE VARCHAR(MAX),
    SUPPLYTYPE VARCHAR(MAX),
    SUPPLYPEGQTY FLOAT,
    DMDPEGQTY FLOAT,
    SUPPLYSEQNUM VARCHAR(MAX),
    SUPPLYITEM VARCHAR(MAX),
    SUPPLYLOC VARCHAR(MAX),
    SUPPLYAVAILDATE DATE,
    DMDSCHEDDATE DATE,
    DMDNEEDDATE DATE,
    LOC VARCHAR(MAX),
    SIMULATION_NAME VARCHAR(MAX),
    DMDSUBTYPE VARCHAR(MAX),
    SUPPLYSUBTYPE VARCHAR(MAX),
    DMDNEEDQTY FLOAT,
    PRODCOST FLOAT,
    SOURCINGCOST FLOAT,
    PURCHCOST FLOAT,
    INHANDLINGCOST FLOAT,
    OUTHANDLINGCOST FLOAT,
    INVCARRYINGCOST FLOAT,
    DMDGROUP VARCHAR(MAX),
    CUST VARCHAR(MAX),
    SUPPLYSUBSEQNUM VARCHAR(MAX),
    SCHEDSEQNUM VARCHAR(MAX),
    SUPPLYMETHOD VARCHAR(MAX),
    PARENTSUPPLYMETHOD VARCHAR(MAX),
    INDDMDPRIORITY INT,
    PARENTITEM VARCHAR(MAX),
    PARENTLOC VARCHAR(MAX),
    PARENTSUPPLYTYPE INT,
    PARENTSUPPLYSEQNUM VARCHAR(MAX),
    PARENTSUPPLYSTARTDATE DATE,
    SCHEDSTARTDATE DATE,
    PARENTSUPPLYSCHEDDATE DATE,
    UDC_MTSR_DMDGROUP VARCHAR(MAX),
    UDC_BATCHID VARCHAR(MAX),
    UDC_SALES_ORDERID VARCHAR(MAX),
    UDC_ORIGINAL_SUPPLYMETHOD VARCHAR(MAX),
    UDC_OG_PARENTSUPPLYMETHOD VARCHAR(MAX),
    UDC_CUSTOMER_TYPE VARCHAR(MAX),
    UDC_ORDERID VARCHAR(MAX),
    UDC_DMDSEQNUM VARCHAR(MAX),
    UDC_RELATEDSEQNUM VARCHAR(MAX),
    UDC_PARENT_FG INT,
    UDC_SUPPLY_PARENT VARCHAR(MAX),
    UDC_FG_LOC INT,
    UDC_PARENT_LOC VARCHAR(MAX),
    UDC_SUPPLY_PARENT_LOC VARCHAR(MAX),
    UDC_FG VARCHAR(MAX),
    UDC_SEGMENT VARCHAR(MAX),
    PARENTRELATEDSEQNUM VARCHAR(MAX),
    UDC_PARENTLOC VARCHAR(MAX),
    UDC_RES_SUPPLYMETHOD VARCHAR(MAX),
    UDC_RES_PARENTSUPPLYMETHOD VARCHAR(MAX),
    DMDITEM_GROUP VARCHAR(MAX),
    SUPPLYITEM_GROUP VARCHAR(MAX)
);


""")
# Out:
# Adding ddl:
# CREATE TABLE dbo.INDDMDLINK (
#     DMDITEM VARCHAR(MAX),
#     DMDLOC VARCHAR(MAX),
#     RELATEDSEQNUM VARCHAR(MAX),
#     ORDERID VARCHAR(MAX),
#     SHIPDATE DATE,
#     DMDSEQNUM VARCHAR(MAX),
#     DMDTYPE VARCHAR(MAX),
#     SUPPLYTYPE VARCHAR(MAX),
#     SUPPLYPEGQTY FLOAT,
#     DMDPEGQTY FLOAT,
#     SUPPLYSEQNUM VARCHAR(MAX),
#     SUPPLYITEM VARCHAR(MAX),
#     SUPPLYLOC VARCHAR(MAX),
#     SUPPLYAVAILDATE DATE,
#     DMDSCHEDDATE DATE,
#     DMDNEEDDATE DATE,
#     LOC VARCHAR(MAX),
#     SIMULATION_NAME VARCHAR(MAX),
#     DMDSUBTYPE VARCHAR(MAX),
#     SUPPLYSUBTYPE VARCHAR(MAX),
#     DMDNEEDQTY FLOAT,
#     PRODCOST FLOAT,
#     SOURCINGCOST FLOAT,
#     PURCHCOST FLOAT,
#     INHANDLINGCOST FLOAT,
#     OUTHANDLINGCOST FLOAT,
#     INVCARRYINGCOST FLOAT,
#     DMDGROUP VARCHAR(MAX),
#     CUST VARCHAR(MAX),
#     SUPPLYSUBSEQNUM VARCHAR(MAX),
#     SCHEDSEQNUM VARCHAR(MAX),
#     SUPPLYMETHOD VARCHAR(MAX),
#     PARENTSUPPLYMETHOD VARCHAR(MAX),
# ...

# %%
# At any time you can inspect what training data the package is able to reference
training_data = vn.get_training_data()
training_data
# Out:
#             id training_data_type  \
# 0   107901-sql                sql
# 1    64160-doc      documentation
# 2    68275-sql                sql
# 3   107890-sql                sql
# 4    68299-sql                sql
# ..         ...                ...
# 76  107931-sql                sql
# 77   68347-sql                sql
# 78   68286-sql                sql
# 79   68296-sql                sql
# 80   68350-sql                sql
#
#                                              question  \
# 0   What is the outward sales for all plants, all ...
# 1                                                None
# 2   give me the underutilised resources for decemb...
# 3   What is the inward HR cosumption for coated pl...
# 4   give me the count of items  for which the reso...
# ..                                                ...
# 76  What are the column names and data types of a ...
# 77           give me the details of my overall schema
# 78  give me the underutilised resources for decemb...
# ...

# %%
# You can also add SQL queries to your training data. This is useful if you have some queries already laying around. You can just copy and paste those from your editor to begin generating new SQL.
vn.train(question= "Give me the Resource Utilisation for all Campaign Constraints for all months",
    sql="SELECT DISTINCT LOC AS PLANT, RES AS RESOURCE, STARTDATE, ROUND(PCTUSED, 0) AS RESOURCE_UTILIZATION, ROUND(SUM(UDC_TOTAL_QTY),0) AS TOTAL_QTY, ROUND(AVAILCAP, 0) AS REMAINING_CAPACITY FROM RESPROJSTATIC WHERE loc != '' AND RES LIKE '%DUMMY%' GROUP BY LOC, RES, STARTDATE, PCTUSED, AVAILCAP ORDER BY RESOURCE_UTILIZATION DESC;")
# Out:
# True

# %%
# You can also add SQL queries to your training data. This is useful if you have some queries already laying around. You can just copy and paste those from your editor to begin generating new SQL.
vn.train(sql="SELECT TABLE_CATALOG, TABLE_SCHEMA,TABLE_NAME, COLUMN_NAME, DATA_TYPE FROM INFORMATION_SCHEMA.COLUMNS where TABLE_CATALOG = 'GEN_AI'")
# Out:
# Question generated with sql: What are the column names and data types of all tables in the 'GEN_AI' database?
# Adding SQL...
# True

# %%
# At any time you can inspect what training data the package is able to reference
training_data = vn.get_training_data()
training_data
# Out:
#             id training_data_type  \
# 0   107901-sql                sql
# 1    64160-doc      documentation
# 2    68275-sql                sql
# 3   107890-sql                sql
# 4    68299-sql                sql
# ..         ...                ...
# 72  107931-sql                sql
# 73   68347-sql                sql
# 74   68286-sql                sql
# 75   68296-sql                sql
# 76   68350-sql                sql
#
#                                              question  \
# 0   What is the outward sales for all plants, all ...
# 1                                                None
# 2   give me the underutilised resources for decemb...
# 3   What is the inward HR cosumption for coated pl...
# 4   give me the count of items  for which the reso...
# ..                                                ...
# 72  What are the column names and data types of a ...
# 73           give me the details of my overall schema
# 74  give me the underutilised resources for decemb...
# ...

# %%
# This code will basically save the csv file where the training data is there stored Run this if you want to see t-data in csv
import pandas as pd
training_data.to_csv('training_data.csv', index=False)

# %%
# You can remove training data if there's obsolete/incorrect information. 
vn.remove_training_data(id='133198-doc')
# Out:
# True

# %%
vn.ask(question= "What is the maximum throughput for each resource in the PPGI supply sequence?")


 # To calculate How to utilise my UnderUtilise Resources
# Out:
# SELECT DISTINCT r.RES, r.MAXTPH
# FROM RESPROJSTATIC r
# WHERE r.ITEM IN ('GI', 'CRFH', 'HR', 'SLAB', 'HOT_METAL')
#     AND r.RES NOT LIKE '%DUMMY%'
# ORDER BY r.RES;
# Empty DataFrame
# Columns: [RES, MAXTPH]
# Index: []
# AI-generated follow-up questions:
#
# * What is the estimated coverage demand for each resource in the PPGI supply sequence?
# * What is the resource utilization for each resource in the PPGI supply sequence?
# * What is the planned quantity for each resource in the PPGI supply sequence?
# * What is the increase in demand for each resource in the PPGI supply sequence?
# * What is the total supply quantity for each plant in the PPGI supply sequence?
# * What is the sourcing cost for each item in the sourcing table?
# * What is the lead time for each item in the sourcing table?
# * What is the draw quantity for each item in the BOM table?
# * What is the discontinued date for each item in the BOM table?
# ...

# %%
sql, df, fig, followup_questions = vn.ask(question= "give me the underutilised resources monthwise",
            print_results = False,
            auto_train = True)

# %%
followup_questions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 followup_questions
#
# NameError: name 'followup_questions' is not defined
